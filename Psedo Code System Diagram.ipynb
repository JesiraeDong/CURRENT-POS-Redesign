# %% [markdown]
# ## WebSockets/MQTT - Real-time Communication

# %%
Initialize WebSocket Server:
    Start WebSocket server on port 8080

On WebSocket Connection (client):
    Receive user message from Guest Book
    Send message to AI Sentiment Analysis
    Wait for response
    Forward AI response to user device (POS or Mobile App)

On WebSocket Connection (business dashboard):
    Send aggregated sentiment data periodically
    Display real-time updates in the business dashboard

# %% [markdown]
# ## AI Sentiment Analysis

# %%
Function analyzeSentiment(message):
    If message contains positive words:
        Return "positive"
    Else if message contains negative words:
        Return "negative"
    Else:
        Return "neutral"

# %% [markdown]
# ## AI Response Generation with emoji

# %%
Function generateResponse(sentiment, message):
    If sentiment == "positive":
        Return "Thank you for your kind words! We appreciate you. 🎉"
    Else if sentiment == "negative":
        Return "I'm sorry to hear that. We value your feedback! 💙"
    Else:
        Return "Thanks for sharing! Let us know if we can help. 😊"

# %% [markdown]
# ## Spotify API Integration

# %%
Function getSpotifyPlaylist(sentiment):
    If sentiment == "positive":
        Return SpotifyAPI.fetch("Happy Vibes Playlist")
    Else if sentiment == "negative":
        Return SpotifyAPI.fetch("Comforting Songs Playlist")
    Else:
        Return SpotifyAPI.fetch("Chill Lo-Fi Beats")

# %% [markdown]
# ##  Data Storage & Retrieval (Database)

# %%
Function storeMessage(userID, message, sentiment, response):
    Database.store({
        "userID": userID,
        "message": message,
        "sentiment": sentiment,
        "response": response,
        "timestamp": currentTime()
    })

Function retrieveMessages(userID):
    Return Database.query("SELECT * FROM messages WHERE userID = ?", userID)

# %% [markdown]
# ## System Diagram

# %%
from IPython.display import Image, display

image_path = "/Users/jesiraedong/Desktop/Screenshot 2025-02-19 at 23.43.38.png"
display(Image(filename=image_path))
